# %% [markdown]
# <a href="https://colab.research.google.com/github/Shenbagalakshmi123/Capstoneproject_module2_RSL/blob/main/Repractice_Module2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
imdb_df = pd.read_csv('/content/drive/My Drive/Almafiles/imdb_data.csv')

# %%
imdb_df.head(5)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
imdb_df.tail(5)
# Out:
#         id belongs_to_collection    budget  \
# 2995  2996                   NaN         0
# 2996  2997                   NaN         0
# 2997  2998                   NaN  65000000
# 2998  2999                   NaN  42000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                               homepage    imdb_id original_language  \
# 2995                               NaN  tt0109403                en
# 2996                               NaN  tt2364975                sv
# 2997                               NaN  tt0116908                en
# 2998    http://www.alongcamepolly.com/  tt0343135                en
# ...

# %%
imdb_df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
imdb_df[['id','title','original_language','cast']]
# Out:
#         id                                     title original_language  \
# 0        1                    Hot Tub Time Machine 2                en
# 1        2  The Princess Diaries 2: Royal Engagement                en
# 2        3                                  Whiplash                en
# 3        4                                   Kahaani                hi
# 4        5                                Marine Boy                ko
# ...    ...                                       ...               ...
# 2995  2996                                   Chasers                en
# 2996  2997                          We Are the Best!                sv
# 2997  2998                   The Long Kiss Goodnight                en
# 2998  2999                          Along Came Polly                en
# 2999  3000                                 Abduction                en
#
#                                                    cast
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
list(imdb_df.columns)
# Out:
# ['id',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'Keywords',
#  'cast',
#  'crew',
#  'revenue']

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
imdb_df.rename(columns={'crew':'actors'}, inplace = True)
imdb_df.head(2)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
#
#                                               genres homepage    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0368933
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
#
#   release_date runtime                          spoken_languages    status  \
# ...

# %%
imdb_df.rename(columns = {'actors':'crew'},inplace = True)
imdb_df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
imdb_df.sort_values('revenue',ascending = False).head(5)
# Out:
#         id                              belongs_to_collection     budget  \
# 1126  1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
# 1761  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
# 2770  2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 684    685                                                NaN  160000000
# 2322  2323  [{'id': 8650, 'name': 'Transformers Collection...  195000000
#
#                                                  genres  \
# 1126  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1761                     [{'id': 28, 'name': 'Action'}]
# 2770  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 684   [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 2322  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
#
#                                                homepage    imdb_id  \
# 1126                  http://marvel.com/avengers_movie/  tt0848228
# ...

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
imdb_df = pd.read_csv('/content/drive/My Drive/Almafiles/imdb_data.csv')

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
imdb_df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
imdb_df[['original_title','cast','crew','original_language','revenue']]
# Out:
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...

# %%
imdb_df.rename(columns = {'budget':'amount_spent'},inplace = True)
#

# %%
imdb_df[['original_title','amount-spent']]
# Out:
#                                 original_title  amount-spent
# 0                       Hot Tub Time Machine 2      14000000
# 1     The Princess Diaries 2: Royal Engagement      40000000
# 2                                     Whiplash       3300000
# 3                                      Kahaani       1200000
# 4                                         마린보이             0
# ...                                        ...           ...
# 2995                                   Chasers             0
# 2996                               Vi är bäst!             0
# 2997                   The Long Kiss Goodnight      65000000
# 2998                          Along Came Polly      42000000
# 2999                                 Abduction      35000000
#
# [3000 rows x 2 columns]

# %%
imdb_df.rename(columns = {'amount-spent':'budget'}, inplace = True)

# %%
imdb_df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
imdb_df.sort_values('runtime',ascending = True)
# Out:
#         id                              belongs_to_collection    budget  \
# 2785  2786                                                NaN         0
# 2865  2866  [{'id': 188197, 'name': 'Cetto La Qualunque - ...   5579750
# 2645  2646                                                NaN         0
# 591    592                                                NaN         0
# 390    391                                                NaN   6843500
# ...    ...                                                ...       ...
# 523    524                                                NaN  13000000
# 1922  1923                                                NaN  31115000
# 1211  1212                                                NaN  18000000
# 1335  1336                                                NaN   6000000
# 2302  2303                                                NaN         0
#
#                                                  genres homepage    imdb_id  \
# ...

# %%
imdb_df.sort_values('runtime',ascending = False).head(5)[['original_title','original_language','runtime']]
# Out:
#             original_title original_language  runtime
# 1211                Carlos                en    338.0
# 1922             Cleopatra                en    248.0
# 523   The Ten Commandments                en    220.0
# 1302         Heaven's Gate                en    219.0
# 1914     Gods and Generals                en    214.0

# %%
imdb_df.iloc[1:20,-4:-8:-1]
# Out:
#                                              Keywords  \
# 1   [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2   [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3   [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   [{'id': 917, 'name': 'journalism'}, {'id': 163...
# 8   [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
# 9   [{'id': 11800, 'name': 'mockumentary'}, {'id':...
# 10  [{'id': 240, 'name': 'underdog'}, {'id': 276, ...
# 11  [{'id': 5801, 'name': 'nerd'}, {'id': 6876, 'n...
# 12  [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# 13  [{'id': 3605, 'name': 'baseball bat'}, {'id': ...
# 14  [{'id': 476, 'name': 'self-fulfilling prophecy...
# 15  [{'id': 379, 'name': 'skinhead'}, {'id': 7492,...
# 16  [{'id': 1562, 'name': 'hostage'}, {'id': 2250,...
# ...

# %%
imdb_df.loc[1:20:2,['original_title','original_language','runtime']]
# Out:
#                                 original_title original_language  runtime
# 1     The Princess Diaries 2: Royal Engagement                en    113.0
# 3                                      Kahaani                hi    122.0
# 5       Pinocchio and the Emperor of the Night                en     83.0
# 7                                 Control Room                en     84.0
# 9                                A Mighty Wind                en     91.0
# 11  Revenge of the Nerds II: Nerds in Paradise                en     98.0
# 13                                     Be Cool                en    118.0
# 15                                     Šišanje                sr     97.0
# 17                         The Invisible Woman                en    111.0
# 19                               Transporter 2                en     87.0

# %%
imdb_df.sort_values('budget',ascending = False).head(5)[['original_title','budget']]
# Out:
#                                    original_title     budget
# 2135  Pirates of the Caribbean: On Stranger Tides  380000000
# 2209     Pirates of the Caribbean: At World's End  300000000
# 2770                      Avengers: Age of Ultron  280000000
# 1425                             Superman Returns  270000000
# 1270                                  John Carter  260000000

# %%
english_movies = imdb_df.loc[:,'original_language'] == 'en'

# %%
english_movies.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: original_language, dtype: bool

# %%
df1 = imdb_df.loc[:,'original_language']=='hi'
df1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: original_language, Length: 3000, dtype: bool

# %%
df1.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: original_language, dtype: bool

# %%
filter = imdb_df.loc[:,'original_language']=='en'

# %%
x = imdb_df[filter]

# %%
x
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
filter = imdb_df.loc[:,'original_language']=='hi'
y = imdb_df[filter]
y
# Out:
# Empty DataFrame
# Columns: [id, belongs_to_collection, budget, genres, homepage, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, runtime, spoken_languages, status, tagline, title, Keywords, cast, crew, revenue]
# Index: []
#
# [0 rows x 23 columns]

# %%
imdb_df.loc[:,'hrt']=imdb_df.loc[:,'runtime']*0.5

# %%
imdb_df[['original_title','runtime','hrt']]
# Out:
#                                 original_title  runtime   hrt
# 0                       Hot Tub Time Machine 2     93.0  46.5
# 1     The Princess Diaries 2: Royal Engagement    113.0  56.5
# 2                                     Whiplash    105.0  52.5
# 3                                      Kahaani    122.0  61.0
# 4                                         마린보이    118.0  59.0
# ...                                        ...      ...   ...
# 2995                                   Chasers    102.0  51.0
# 2996                               Vi är bäst!    102.0  51.0
# 2997                   The Long Kiss Goodnight    120.0  60.0
# 2998                          Along Came Polly     90.0  45.0
# 2999                                 Abduction    106.0  53.0
#
# [3000 rows x 3 columns]

# %%
imdb_df.rename(columns = {'hrt':'half_run_time'}, inplace = True)
imdb_df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
imdb_df.loc[:,'profit'] = imdb_df.loc[:,'revenue'] - imdb_df.loc[:,'budget']
imdb_df[['original_title','revenue','budget','profit']]
# Out:
#                                 original_title    revenue    budget     profit
# 0                       Hot Tub Time Machine 2   12314651  14000000   -1685349
# 1     The Princess Diaries 2: Royal Engagement   95149435  40000000   55149435
# 2                                     Whiplash   13092000   3300000    9792000
# 3                                      Kahaani   16000000   1200000   14800000
# 4                                         마린보이    3923970         0    3923970
# ...                                        ...        ...       ...        ...
# 2995                                   Chasers    1596687         0    1596687
# 2996                               Vi är bäst!     180590         0     180590
# 2997                   The Long Kiss Goodnight   89456761  65000000   24456761
# 2998                          Along Came Polly  171963386  42000000  129963386
# 2999                                 Abduction   82087155  35000000   47087155
#
# [3000 rows x 4 columns]

# %%
imdb_df.loc[:,'no profit']= imdb_df.loc[:,'profit']<0

# %%
imdb_df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
imdb_df.drop('profit', inplace = True, axis = 1)

# %%
imdb_df.iloc[:,-1:-8:-1]
# Out:
#       no profit  half_run_time    revenue  \
# 0          True           46.5   12314651
# 1         False           56.5   95149435
# 2         False           52.5   13092000
# 3         False           61.0   16000000
# 4         False           59.0    3923970
# ...         ...            ...        ...
# 2995      False           51.0    1596687
# 2996      False           51.0     180590
# 2997      False           60.0   89456761
# 2998      False           45.0  171963386
# 2999      False           53.0   82087155
#
#                                                    crew  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...
# ...                                                 ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...
# ...

# %%
imdb_df.drop('half_run_time', inplace = True, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-64dda91b7e9c> in <cell line: 1>()
# ----> 1 imdb_df.drop('half_run_time', inplace = True, axis = 1)
#       2 imdb_df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
imdb_df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
def to_upper(col):
  return col.upper()

# %%
word = 'people'
to_upper(word)
# Out:
# 'PEOPLE'

# %%
imdb_df['capitalized_title']=imdb_df['title'].apply(to_upper)

# %%
imdb_df.iloc[:,-1:-8:-1]
# Out:
#                              capitalized_title  no profit    revenue  \
# 0                       HOT TUB TIME MACHINE 2       True   12314651
# 1     THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT      False   95149435
# 2                                     WHIPLASH      False   13092000
# 3                                      KAHAANI      False   16000000
# 4                                   MARINE BOY      False    3923970
# ...                                        ...        ...        ...
# 2995                                   CHASERS      False    1596687
# 2996                          WE ARE THE BEST!      False     180590
# 2997                   THE LONG KISS GOODNIGHT      False   89456761
# 2998                          ALONG CAME POLLY      False  171963386
# 2999                                 ABDUCTION      False   82087155
#
#                                                    crew  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...
# ...

# %%
def to_lower(col):
  return col.lower()

# %%
word = 'POP'
to_lower(word)
# Out:
# 'pop'

# %%
imdb_df['lowercase_title']=imdb_df['capitalized_title'].apply(to_lower)

# %%
imdb_df[['capitalized_title','lowercase_title','title']]
# Out:
#                              capitalized_title  \
# 0                       HOT TUB TIME MACHINE 2
# 1     THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 2                                     WHIPLASH
# 3                                      KAHAANI
# 4                                   MARINE BOY
# ...                                        ...
# 2995                                   CHASERS
# 2996                          WE ARE THE BEST!
# 2997                   THE LONG KISS GOODNIGHT
# 2998                          ALONG CAME POLLY
# 2999                                 ABDUCTION
#
#                                lowercase_title  \
# 0                       hot tub time machine 2
# 1     the princess diaries 2: royal engagement
# 2                                     whiplash
# 3                                      kahaani
# 4                                   marine boy
# ...                                        ...
# 2995                                   chasers
# ...

# %%
import numpy as np
def revised_profit(revenue,budget):
  if revenue > 0:
    new_profit = revenue - budget
  else:
    new_profit = np.nan
  return new_profit

# %%
imdb_df['revised_profit'] = imdb_df.apply(lambda x: revised_profit(x['revenue'], x['budget']),axis = 1)

# %%
imdb_df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
imdb1 = imdb_df[imdb_df['runtime']>=150]
imdb1.head(5)
# Out:
#       id belongs_to_collection    budget  \
# 47    48                   NaN  44000000
# 51    52                   NaN  12000000
# 76    77                   NaN    500000
# 97    98                   NaN         0
# 107  108                   NaN  72000000
#
#                                                 genres  \
# 47   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51   [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97   [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#                         homepage    imdb_id original_language  \
# 47   http://thehatefuleight.com/  tt3460252                en
# 51                           NaN  tt0059243                en
# 76                           NaN  tt0242572                en
# 97                           NaN  tt1772980                en
# 107                          NaN  tt0112573                en
#
# ...

# %%
imdb1[['title','runtime']]
# Out:
#                           title  runtime
# 47            The Hateful Eight    167.0
# 51               The Great Race    160.0
# 76    Kandukondain Kandukondain    157.0
# 97                       Target    158.0
# 107                  Braveheart    177.0
# ...                         ...      ...
# 2860                     Gandhi    191.0
# 2877                    Amadeus    160.0
# 2932           The Sand Pebbles    182.0
# 2944             Apocalypse Now    153.0
# 2965             Les Misérables    157.0
#
# [135 rows x 2 columns]

# %%
imdb2 = imdb_df[(imdb_df['runtime']<150) & (imdb_df['runtime']>100)]

# %%
imdb2
# Out:
#         id                              belongs_to_collection    budget  \
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# 10      11  [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
# ...    ...                                                ...       ...
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
imdb1.shape
# Out:
# (135, 27)

# %%
imdb2.shape
# Out:
# (1586, 27)

# %%
imdb_dfnew = pd.concat([imdb1,imdb2],axis = 0)
imdb_dfnew
# Out:
#         id belongs_to_collection    budget  \
# 47      48                   NaN  44000000
# 51      52                   NaN  12000000
# 76      77                   NaN    500000
# 97      98                   NaN         0
# 107    108                   NaN  72000000
# ...    ...                   ...       ...
# 2994  2995                   NaN         0
# 2995  2996                   NaN         0
# 2996  2997                   NaN         0
# 2997  2998                   NaN  65000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 47    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51    [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97    [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# ...                                                 ...
# ...

# %%
imdb_dfnew1 = pd.concat([imdb1,imdb2], axis = 1)

# %%
imdb_dfnew1
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py:700: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# /usr/local/lib/python3.10/dist-packages/google/colab/_interactive_table_hint_button.py:178: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_html=dataframe._repr_html_(),  # pylint: disable=protected-access
#          id belongs_to_collection      budget  \
# 47     48.0                   NaN  44000000.0
# 51     52.0                   NaN  12000000.0
# 76     77.0                   NaN    500000.0
# 97     98.0                   NaN         0.0
# 107   108.0                   NaN  72000000.0
# ...     ...                   ...         ...
# 2994    NaN                   NaN         NaN
# ...

# %%
y
# Out:
# Empty DataFrame
# Columns: [id, belongs_to_collection, budget, genres, homepage, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, runtime, spoken_languages, status, tagline, title, Keywords, cast, crew, revenue]
# Index: []
#
# [0 rows x 23 columns]

# %%
df_new = pd.merge(imdb1,imdb2,how='right',on = 'original_language')

# %%
df_new.head(5)
# Out:
#    id_x belongs_to_collection_x  budget_x  \
# 0    48                     NaN  44000000
# 1    52                     NaN  12000000
# 2    77                     NaN    500000
# 3    98                     NaN         0
# 4   108                     NaN  72000000
#
#                                             genres_x  \
# 0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 3  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#                     homepage_x  imdb_id_x original_language  \
# 0  http://thehatefuleight.com/  tt3460252                en
# 1                          NaN  tt0059243                en
# 2                          NaN  tt0242572                en
# 3                          NaN  tt1772980                en
# 4                          NaN  tt0112573                en
#
# ...

# %%
result = imdb1.groupby('original_language')

# %%
for name,group in result:
  print(name)
  print(group)
# Out:
# en
#         id belongs_to_collection    budget  \
# 47      48                   NaN  44000000
# 51      52                   NaN  12000000
# 76      77                   NaN    500000
# 97      98                   NaN         0
# 107    108                   NaN  72000000
# ...    ...                   ...       ...
# 2860  2861                   NaN  22000000
# 2877  2878                   NaN  18000000
# 2932  2933                   NaN  12000000
# 2944  2945                   NaN  31500000
# 2965  2966                   NaN  61000000
#
#                                                  genres  \
# 47    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51    [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97    [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# ...                                                 ...
# ...

# %%
res = imdb1.groupby('original_language')['runtime'].max()
res.head()
# Out:
# original_language
# en    338.0
# Name: runtime, dtype: float64

# %%
res1 = imdb1.groupby('original_language')['runtime'].min()
res1.head()
# Out:
# original_language
# en    150.0
# Name: runtime, dtype: float64

# %%
imdb1.sort_values('runtime',ascending = True).head()[['original_title','original_language','runtime']]
# Out:
#             original_title original_language  runtime
# 462                Contact                en    150.0
# 2828       Bajirao Mastani                en    150.0
# 1808            Ônibus 174                en    150.0
# 2688  The Raid 2: Berandal                en    150.0
# 1899   Deewane Huye Paagal                en    150.0

# %%
res1 = imdb1.groupby('original_language').agg({'runtime':['min','max','mean']})

# %%
res1.head
# Out:
# <bound method NDFrame.head of                   runtime
#                       min    max       mean
# original_language
# en                  150.0  338.0  169.02963>

# %%
imdb1_new = imdb1.groupby(['original_language','id'])

# %%
for name,group in imdb1_new:
  print(name)
  print(group)
# Out:
# ('en', 48)
#     id belongs_to_collection    budget  \
# 47  48                   NaN  44000000
#
#                                                genres  \
# 47  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
#
#                        homepage    imdb_id original_language  \
# 47  http://thehatefuleight.com/  tt3460252                en
#
#        original_title                                           overview  \
# 47  The Hateful Eight  Bounty hunters seek shelter from a raging bliz...
#
#     popularity  ...                                           tagline  \
# 47   20.328822  ...  No one comes up here without a damn good reason.
#
#                 title                                           Keywords  \
# 47  The Hateful Eight  [{'id': 801, 'name': 'bounty hunter'}, {'id': ...
#
#                                                  cast  \
# 47  [{'cast_id': 22, 'character': 'Major Marquis W...
#
# ...

# %%
imdb1_g1 = imdb1.groupby('original_language')

# %%
imdb1_g1.size()
# Out:
# original_language
# en    135
# dtype: int64

# %%
imdb_g2 = imdb1.groupby(['original_language','id'])

# %%
imdb_g2.size()
# Out:
# original_language  id
# en                 48      1
#                    52      1
#                    77      1
#                    98      1
#                    108     1
#                           ..
#                    2861    1
#                    2878    1
#                    2933    1
#                    2945    1
#                    2966    1
# Length: 135, dtype: int64
